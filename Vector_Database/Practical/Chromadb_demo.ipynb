# %%
# Step 1 write pip install chromadb
#Step2L for check : write below code 
import chromadb

client = chromadb.Client()
print("ChromaDB successfully installed!")
# Out:
# ChromaDB successfully installed!
